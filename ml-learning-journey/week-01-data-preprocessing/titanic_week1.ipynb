# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-3305111549.py in <cell line: 0>()
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
num = 5 + 3j
print(num)
type(num)
# Out:
# (5+3j)
# complex

# %%
num_int = int(5.7)
type(num_int)
# Out:
# int

# %%
num_float=("3.14")
type(num_float)
# Out:
# str

# %%
message = str(42)
type(int)
# Out:
# type

# %%
is_true=bool(1)
is_flase=bool(0)
type(bool)
# Out:
# type

# %%
char_a= 'A'
char_b= 'B'
ascill_value_a = ord(char_a)
ascill_value_b = ord(char_b)
print("ASCILL value of 'A' is:",ascill_value_a)
print("ASCILL value of 'B' is:",ascill_value_b)
# Out:
# ASCILL value of 'A' is: 65
# ASCILL value of 'B' is: 66

# %%
ascill_value = 65
character = chr(ascill_value)
print("ASCILL VALUE IS 65:",character)
# Out:
# ASCILL VALUE IS 65: A

# %%
a=2
b=3
c=a+b
print(c)
# Out:
# 5

# %%
a = 50
b = 15
c = a % b
print("Module :",c)
# Out:
# Module : 5

# %%
x = 10
print("value of x:",x)
# Out:
# value of x: 10

# %%
y = 10
y += 20
print("value of y:",y)
# Out:
# value of y: 30

# %%
z = 50
z -= 30
print("value of z:",z)
# Out:
# value of z: 20

# %%
r = 15
s = 10
pravan = r >= s
print(pravan)
# Out:
# True

# %%
a = True
b = False
pravan = not a
print(pravan)
# Out:
# False

# %%
t = [1,2,3]
print (1 in t) # check wheather 1 in the list
print ( 10, not t)# check wheather 10 in the list
# Out:
# True
# 10 False

# %%
name1 = "pravan"
name2 = "pravan"
c = name1 is not name2
print (c)
# Out:
# False

# %%
a = 10
b = 20
c = a is not b
print (c)
# Out:
# True

# %%
a = 2 << 2
print(a)
# Out:
# 8

# %%
 num = int(input("give the value of num"))
print("You enterd:","num")
